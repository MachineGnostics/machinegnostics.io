# %%
# install machine gnostic learning packages
# ! pip install machinegnostics # only if not installed

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Robust regression and mlflow integration

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import mlflow
import os
import mlflow.pyfunc
from mlflow.models.signature import infer_signature
from machinegnostics.models.regression import PolynomialRegressor
from machinegnostics.metrics import hc, robr2, root_mean_squared_error
import matplotlib.pyplot as plt

# --- Train PolynomialRegressor ---
X = np.random.rand(100, 2)
y = np.random.rand(100)
model = PolynomialRegressor(degree=3, mg_loss='hi', verbose=True)
model.fit(X, y)

# --- MLflow Logging ---
input_example = pd.DataFrame(X, columns=["feature1", "feature2"])
signature = infer_signature(input_example, model.predict(input_example))

y_pred = model.predict(X)
hc_score = hc(y, y_pred)
rob_r2_score = robr2(y, y_pred)
rmse_score = root_mean_squared_error(y, y_pred)

# set experiment name
mlflow.set_experiment("GnosticPolynomialRegressorExperiment")
# ensure the experiment exists
experiment = mlflow.get_experiment_by_name("GnosticPolynomialRegressorExperiment")
if experiment is None:
    mlflow.create_experiment("GnosticPolynomialRegressorExperiment")

with mlflow.start_run():
    mlflow.pyfunc.log_model(
        artifact_path="robust_regressor",
        python_model=model,
        registered_model_name="GnosticPolynomialRegressor",
        input_example=input_example,
        signature=signature
    )
    mlflow.log_metric("hc", hc_score)
    mlflow.log_metric("rob_r2", rob_r2_score)
    mlflow.log_metric("rmse", rmse_score)
# Out:
# 2025/06/04 11:58:23 INFO mlflow.tracking.fluent: Experiment with name 'GnosticPolynomialRegressorExperiment' does not exist. Creating a new experiment.
# 2025/06/04 11:58:23 INFO mlflow.pyfunc: Validating input example against model signature
# Iteration: 1 - Machine Gnostic loss - hi : 91.3463, rentropy: 0.1182
# Iteration: 2 - Machine Gnostic loss - hi : 91.2682, rentropy: 0.1216
# Iteration: 3 - Machine Gnostic loss - hi : 91.2757, rentropy: 0.1255
# Iteration: 4 - Machine Gnostic loss - hi : 91.2844, rentropy: 0.1256
# Iteration: 5 - Machine Gnostic loss - hi : 91.2899, rentropy: 0.1247
# Iteration: 6 - Machine Gnostic loss - hi : 91.2924, rentropy: 0.124
# Iteration: 7 - Machine Gnostic loss - hi : 91.2934, rentropy: 0.1236
# Iteration: 8 - Machine Gnostic loss - hi : 91.2939, rentropy: 0.1233
# Iteration: 9 - Machine Gnostic loss - hi : 91.2941, rentropy: 0.1233
# Iteration: 10 - Machine Gnostic loss - hi : 91.2942, rentropy: 0.1233
# Iteration: 11 - Machine Gnostic loss - hi : 91.2941, rentropy: 0.1233
# Iteration: 12 - Machine Gnostic loss - hi : 91.2938, rentropy: 0.1233
# Iteration: 13 - Machine Gnostic loss - hi : 91.2933, rentropy: 0.1233
# Iteration: 14 - Machine Gnostic loss - hi : 91.2928, rentropy: 0.1232
# Iteration: 15 - Machine Gnostic loss - hi : 91.2923, rentropy: 0.1232
# Iteration: 16 - Machine Gnostic loss - hi : 91.2917, rentropy: 0.1232
# Iteration: 17 - Machine Gnostic loss - hi : 91.2912, rentropy: 0.1232
# Iteration: 18 - Machine Gnostic loss - hi : 91.2908, rentropy: 0.1232
# Iteration: 19 - Machine Gnostic loss - hi : 91.2904, rentropy: 0.1232
# Iteration: 20 - Machine Gnostic loss - hi : 91.2901, rentropy: 0.1232
# Iteration: 21 - Machine Gnostic loss - hi : 91.2898, rentropy: 0.1232
# Iteration: 22 - Machine Gnostic loss - hi : 91.2896, rentropy: 0.1232
# Iteration: 23 - Machine Gnostic loss - hi : 91.2894, rentropy: 0.1232
# Iteration: 24 - Machine Gnostic loss - hi : 91.2893, rentropy: 0.1232
# Iteration: 25 - Machine Gnostic loss - hi : 91.2891, rentropy: 0.1232
# Iteration: 26 - Machine Gnostic loss - hi : 91.289, rentropy: 0.1232
# Iteration: 27 - Machine Gnostic loss - hi : 91.2889, rentropy: 0.1232
# Iteration: 28 - Machine Gnostic loss - hi : 91.2888, rentropy: 0.1233
# Iteration: 29 - Machine Gnostic loss - hi : 90.7053, rentropy: 0.5396
# Iteration: 30 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 31 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 32 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 33 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 34 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 35 - Machine Gnostic loss - hi : 91.2887, rentropy: 0.1233
# Iteration: 36 - Machine Gnostic loss - hi : 91.2888, rentropy: 0.1233
# Iteration: 37 - Machine Gnostic loss - hi : 91.2889, rentropy: 0.1233
# Iteration: 38 - Machine Gnostic loss - hi : 91.289, rentropy: 0.1233
# Iteration: 39 - Machine Gnostic loss - hi : 91.2891, rentropy: 0.1233
# Iteration: 40 - Machine Gnostic loss - hi : 91.2893, rentropy: 0.1233
# Iteration: 41 - Machine Gnostic loss - hi : 91.2894, rentropy: 0.1233
# Iteration: 42 - Machine Gnostic loss - hi : 91.2896, rentropy: 0.1233
# Iteration: 43 - Machine Gnostic loss - hi : 91.2898, rentropy: 0.1234
# Iteration: 44 - Machine Gnostic loss - hi : 91.29, rentropy: 0.1234
# Iteration: 45 - Machine Gnostic loss - hi : 91.2902, rentropy: 0.1234
# Iteration: 46 - Machine Gnostic loss - hi : 91.2904, rentropy: 0.1234
# Iteration: 47 - Machine Gnostic loss - hi : 91.2907, rentropy: 0.1234
# Iteration: 48 - Machine Gnostic loss - hi : 91.2909, rentropy: 0.1234
# Iteration: 49 - Machine Gnostic loss - hi : 91.2912, rentropy: 0.1234
# Iteration: 50 - Machine Gnostic loss - hi : 91.2914, rentropy: 0.1234
# Iteration: 51 - Machine Gnostic loss - hi : 91.2917, rentropy: 0.1234
# Iteration: 52 - Machine Gnostic loss - hi : 91.292, rentropy: 0.1234
# Iteration: 53 - Machine Gnostic loss - hi : 91.2923, rentropy: 0.1234
# Iteration: 54 - Machine Gnostic loss - hi : 91.2926, rentropy: 0.1234
# Iteration: 55 - Machine Gnostic loss - hi : 91.293, rentropy: 0.1235
# Iteration: 56 - Machine Gnostic loss - hi : 91.2933, rentropy: 0.1235
# Iteration: 57 - Machine Gnostic loss - hi : 91.2936, rentropy: 0.1235
# Iteration: 58 - Machine Gnostic loss - hi : 91.294, rentropy: 0.1235
# Iteration: 59 - Machine Gnostic loss - hi : 91.2944, rentropy: 0.1235
# Iteration: 60 - Machine Gnostic loss - hi : 91.2947, rentropy: 0.1235
# Iteration: 61 - Machine Gnostic loss - hi : 91.2951, rentropy: 0.1235
# Iteration: 62 - Machine Gnostic loss - hi : 91.2955, rentropy: 0.1235
# Iteration: 63 - Machine Gnostic loss - hi : 91.2959, rentropy: 0.1235
# Iteration: 64 - Machine Gnostic loss - hi : 91.2963, rentropy: 0.1235
# Iteration: 65 - Machine Gnostic loss - hi : 91.2967, rentropy: 0.1236
# Iteration: 66 - Machine Gnostic loss - hi : 91.2972, rentropy: 0.1236
# Iteration: 67 - Machine Gnostic loss - hi : 91.2976, rentropy: 0.1236
# Iteration: 68 - Machine Gnostic loss - hi : 91.2981, rentropy: 0.1236
# Iteration: 69 - Machine Gnostic loss - hi : 91.2985, rentropy: 0.1236
# Iteration: 70 - Machine Gnostic loss - hi : 91.299, rentropy: 0.1236
# Iteration: 71 - Machine Gnostic loss - hi : 91.2995, rentropy: 0.1236
# Iteration: 72 - Machine Gnostic loss - hi : 91.2999, rentropy: 0.1236
# Iteration: 73 - Machine Gnostic loss - hi : 91.3004, rentropy: 0.1237
# Iteration: 74 - Machine Gnostic loss - hi : 91.3009, rentropy: 0.1237
# Iteration: 75 - Machine Gnostic loss - hi : 91.3014, rentropy: 0.1237
# Iteration: 76 - Machine Gnostic loss - hi : 91.3019, rentropy: 0.1237
# Iteration: 77 - Machine Gnostic loss - hi : 91.3025, rentropy: 0.1237
# Iteration: 78 - Machine Gnostic loss - hi : 91.303, rentropy: 0.1238
# Iteration: 79 - Machine Gnostic loss - hi : 91.3035, rentropy: 0.1238
# Iteration: 80 - Machine Gnostic loss - hi : 91.304, rentropy: 0.1238
# Iteration: 81 - Machine Gnostic loss - hi : 91.3045, rentropy: 0.1238
# Iteration: 82 - Machine Gnostic loss - hi : 91.3051, rentropy: 0.1238
# Iteration: 83 - Machine Gnostic loss - hi : 91.3056, rentropy: 0.1239
# Iteration: 84 - Machine Gnostic loss - hi : 91.3061, rentropy: 0.1239
# Iteration: 85 - Machine Gnostic loss - hi : 91.3066, rentropy: 0.1239
# Iteration: 86 - Machine Gnostic loss - hi : 91.3072, rentropy: 0.1239
# Iteration: 87 - Machine Gnostic loss - hi : 91.3077, rentropy: 0.124
# Iteration: 88 - Machine Gnostic loss - hi : 91.3082, rentropy: 0.124
# Iteration: 89 - Machine Gnostic loss - hi : 91.3087, rentropy: 0.124
# Iteration: 90 - Machine Gnostic loss - hi : 91.3092, rentropy: 0.124
# Iteration: 91 - Machine Gnostic loss - hi : 91.3097, rentropy: 0.124
# Iteration: 92 - Machine Gnostic loss - hi : 91.3102, rentropy: 0.1241
# Iteration: 93 - Machine Gnostic loss - hi : 91.3107, rentropy: 0.1241
# Iteration: 94 - Machine Gnostic loss - hi : 91.3112, rentropy: 0.1241
# Iteration: 95 - Machine Gnostic loss - hi : 91.3116, rentropy: 0.1241
# Iteration: 96 - Machine Gnostic loss - hi : 91.3121, rentropy: 0.1241
# Iteration: 97 - Machine Gnostic loss - hi : 91.3125, rentropy: 0.1242
# Iteration: 98 - Machine Gnostic loss - hi : 91.3129, rentropy: 0.1242
# Iteration: 99 - Machine Gnostic loss - hi : 91.3134, rentropy: 0.1242
# Iteration: 100 - Machine Gnostic loss - hi : 91.3138, rentropy: 0.1242
# 2025/06/04 11:58:25 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2025-04-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'machinegnostics'}
# Successfully registered model 'GnosticPolynomialRegressor'.
# Created version '1' of model 'GnosticPolynomialRegressor'.

# %% [markdown]
# ## prediction with mlflow

# %%
# for more details check the MLflow UI
# mlflow ui --port 5000

# %%
# --- Load model from MLflow and predict ---
loaded_model = mlflow.pyfunc.load_model("models:/GnosticPolynomialRegressor/1")
X_test = pd.DataFrame(np.random.rand(10, 2), columns=["feature1", "feature2"])
predictions = loaded_model.predict(X_test)
print("Predictions:\n", predictions)
# Out:
# Predictions:
#  [0.28963925 0.26006045 0.66399138 0.58946248 0.65532472 0.39603465
#  0.30940081 0.23480139 0.61346466 0.31523568]

# %% [markdown]
# ## History of params

# %%
# --- Plot model history ---
if isinstance(model._history, list):
    history_df = pd.DataFrame(model._history)
else:
    history_df = pd.DataFrame([model._history])

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()
plot_idx = 0

if 'h_loss' in history_df.columns and history_df['h_loss'].notnull().any():
    axes[plot_idx].plot(history_df['iteration'], history_df['h_loss'], label='h_loss', color='blue')
    axes[plot_idx].set_xlabel('Iteration')
    axes[plot_idx].set_ylabel('h_loss')
    axes[plot_idx].set_title('Gnostic Loss (h_loss) over Iterations')
    axes[plot_idx].legend()
    axes[plot_idx].grid(True, alpha=0.5)
    plot_idx += 1

if 'rentropy' in history_df.columns and history_df['rentropy'].notnull().any():
    axes[plot_idx].plot(history_df['iteration'], history_df['rentropy'], label='rentropy', color='orange')
    axes[plot_idx].set_xlabel('Iteration')
    axes[plot_idx].set_ylabel('Rentropy')
    axes[plot_idx].set_title('Residual Entropy over Iterations')
    axes[plot_idx].legend()
    axes[plot_idx].grid(True, alpha=0.5)
    plot_idx += 1

if 'coefficients' in history_df.columns and history_df['coefficients'].notnull().any():
    coef_norms = history_df['coefficients'].apply(lambda x: np.linalg.norm(x) if x is not None else np.nan)
    axes[plot_idx].plot(history_df['iteration'], coef_norms, label='||coefficients||', color='green')
    axes[plot_idx].set_xlabel('Iteration')
    axes[plot_idx].set_ylabel('Coefficient Norm')
    axes[plot_idx].set_title('Coefficient Norm over Iterations')
    axes[plot_idx].legend()
    axes[plot_idx].grid(True, alpha=0.5)
    plot_idx += 1

if 'weights' in history_df.columns and history_df['weights'].notnull().any():
    mean_weights = history_df['weights'].apply(lambda x: np.mean(x) if x is not None else np.nan)
    axes[plot_idx].plot(history_df['iteration'], mean_weights, label='Mean Weights', color='red')
    axes[plot_idx].set_xlabel('Iteration')
    axes[plot_idx].set_ylabel('Mean Weight')
    axes[plot_idx].set_title('Mean Sample Weight over Iterations')
    axes[plot_idx].legend()
    axes[plot_idx].grid(True, alpha=0.5)
    plot_idx += 1

for i in range(plot_idx, len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.show()
