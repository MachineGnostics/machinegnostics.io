# %%
# install machine gnostic learning packages
# ! pip install machinegnostics # only if not installed

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from ucimlrepo) (2.2.3)
# Requirement already satisfied: certifi>=2020.12.5 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from ucimlrepo) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nirmal/Documents/np_research/ManGo_code/machinegnostics.io/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
# # metadata 
# print(wine_quality.metadata) 
  
# # variable information 
# print(wine_quality.variables)

# %%
X.head()  # Display the first few rows of the features dataframe
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
# importing libraries
from machinegnostics.metrics import gcorrelation
import pandas as pd
import numpy as np

# %%
gcor = gcorrelation(X, y)

# printing the results
print("G-Correlation Results:")
display(gcor.sort_values(ascending=False, by = 'quality'))
# Out:
# G-Correlation Results:
#                        quality
# chlorides             0.982795
# free_sulfur_dioxide   0.982450
# citric_acid           0.981344
# residual_sugar        0.980924
# sulphates             0.980540
# density               0.980064
# fixed_acidity         0.978046
# volatile_acidity      0.976912
# pH                    0.973828
# alcohol               0.970563
# total_sulfur_dioxide  0.970082

# %%
# train test split
from machinegnostics.models import train_test_split

# splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_seed=42)

# %%
# importing machinegnostics regressor model
from machinegnostics.models.regression import PolynomialRegressor

rr = PolynomialRegressor(degree=2, verbose=True, early_stopping=True)

rr.fit(X_train, y_train)
# Out:
# Iteration: 1 - Machine Gnostic loss - hi : 4732.3584, rentropy: 0.6122
# Iteration: 2 - Machine Gnostic loss - hi : 4754.3537, rentropy: 0.6025
# Iteration: 3 - Machine Gnostic loss - hi : 4761.0907, rentropy: 0.5997
# Iteration: 4 - Machine Gnostic loss - hi : 4761.0743, rentropy: 0.599
# Iteration: 5 - Machine Gnostic loss - hi : 4760.5152, rentropy: 0.5985
# Iteration: 6 - Machine Gnostic loss - hi : 4759.6832, rentropy: 0.5983
# Iteration: 7 - Machine Gnostic loss - hi : 4758.6678, rentropy: 0.5981
# Iteration: 8 - Machine Gnostic loss - hi : 4757.6101, rentropy: 0.5979
# Iteration: 9 - Machine Gnostic loss - hi : 4756.5416, rentropy: 0.5977
# Iteration: 10 - Machine Gnostic loss - hi : 4755.5253, rentropy: 0.5974
# Iteration: 11 - Machine Gnostic loss - hi : 4754.5927, rentropy: 0.5971
# Iteration: 12 - Machine Gnostic loss - hi : 4753.7282, rentropy: 0.5968
# Iteration: 13 - Machine Gnostic loss - hi : 4752.971, rentropy: 0.5965
# Iteration: 14 - Machine Gnostic loss - hi : 4752.264, rentropy: 0.5963
# Iteration: 15 - Machine Gnostic loss - hi : 4751.6421, rentropy: 0.596
# Iteration: 16 - Machine Gnostic loss - hi : 4751.0526, rentropy: 0.5957
# Iteration: 17 - Machine Gnostic loss - hi : 4750.4316, rentropy: 0.5956
# Iteration: 18 - Machine Gnostic loss - hi : 4749.9274, rentropy: 0.5954
# Iteration: 19 - Machine Gnostic loss - hi : 4749.3707, rentropy: 0.5952
# Iteration: 20 - Machine Gnostic loss - hi : 4748.7828, rentropy: 0.5951
# Iteration: 21 - Machine Gnostic loss - hi : 4748.1664, rentropy: 0.5951
# Iteration: 22 - Machine Gnostic loss - hi : 4747.5559, rentropy: 0.595
# Iteration: 23 - Machine Gnostic loss - hi : 4746.9131, rentropy: 0.595
# Iteration: 24 - Machine Gnostic loss - hi : 4746.2366, rentropy: 0.595
# Iteration: 25 - Machine Gnostic loss - hi : 4745.4808, rentropy: 0.5951
# Iteration: 26 - Machine Gnostic loss - hi : 4744.679, rentropy: 0.5952
# Iteration: 27 - Machine Gnostic loss - hi : 4743.8821, rentropy: 0.5953
# Iteration: 28 - Machine Gnostic loss - hi : 4743.0054, rentropy: 0.5955
# Iteration: 29 - Machine Gnostic loss - hi : 4742.1698, rentropy: 0.5956
# Iteration: 30 - Machine Gnostic loss - hi : 4741.2739, rentropy: 0.5958
# Iteration: 31 - Machine Gnostic loss - hi : 4740.3225, rentropy: 0.5961
# Iteration: 32 - Machine Gnostic loss - hi : 4739.4058, rentropy: 0.5963
# Iteration: 33 - Machine Gnostic loss - hi : 4738.5132, rentropy: 0.5966
# Iteration: 34 - Machine Gnostic loss - hi : 4737.6113, rentropy: 0.5969
# Iteration: 35 - Machine Gnostic loss - hi : 4736.7291, rentropy: 0.5971
# Iteration: 36 - Machine Gnostic loss - hi : 4735.8912, rentropy: 0.5974
# Iteration: 37 - Machine Gnostic loss - hi : 4735.0818, rentropy: 0.5977
# Iteration: 38 - Machine Gnostic loss - hi : 4734.3115, rentropy: 0.598
# Iteration: 39 - Machine Gnostic loss - hi : 4733.5495, rentropy: 0.5983
# Iteration: 40 - Machine Gnostic loss - hi : 4732.8379, rentropy: 0.5986
# Iteration: 41 - Machine Gnostic loss - hi : 4732.2246, rentropy: 0.5988
# Iteration: 42 - Machine Gnostic loss - hi : 4731.6155, rentropy: 0.599
# Iteration: 43 - Machine Gnostic loss - hi : 4730.9522, rentropy: 0.5993
# Iteration: 44 - Machine Gnostic loss - hi : 4730.4492, rentropy: 0.5995
# Iteration: 45 - Machine Gnostic loss - hi : 4729.9233, rentropy: 0.5997
# Iteration: 46 - Machine Gnostic loss - hi : 4729.3971, rentropy: 0.6
# Iteration: 47 - Machine Gnostic loss - hi : 4728.8542, rentropy: 0.6002
# Iteration: 48 - Machine Gnostic loss - hi : 4728.5117, rentropy: 0.6003
# Iteration: 49 - Machine Gnostic loss - hi : 4727.1134, rentropy: 0.6005
# Iteration: 50 - Machine Gnostic loss - hi : 4727.6148, rentropy: 0.6007
# Iteration: 51 - Machine Gnostic loss - hi : 4727.2883, rentropy: 0.6008
# Iteration: 52 - Machine Gnostic loss - hi : 4726.7635, rentropy: 0.6012
# Iteration: 53 - Machine Gnostic loss - hi : 4726.4144, rentropy: 0.6013
# Iteration: 54 - Machine Gnostic loss - hi : 4726.13, rentropy: 0.6014
# Iteration: 55 - Machine Gnostic loss - hi : 4725.7416, rentropy: 0.6016
# Iteration: 56 - Machine Gnostic loss - hi : 4725.4383, rentropy: 0.6018
# Iteration: 57 - Machine Gnostic loss - hi : 4725.0577, rentropy: 0.602
# Iteration: 58 - Machine Gnostic loss - hi : 4724.7598, rentropy: 0.6021
# Iteration: 59 - Machine Gnostic loss - hi : 4724.465, rentropy: 0.6023
# Iteration: 60 - Machine Gnostic loss - hi : 4724.1404, rentropy: 0.6024
# Iteration: 61 - Machine Gnostic loss - hi : 4723.8988, rentropy: 0.6025
# Iteration: 62 - Machine Gnostic loss - hi : 4723.5338, rentropy: 0.6028
# Iteration: 63 - Machine Gnostic loss - hi : 4723.321, rentropy: 0.6029
# Iteration: 64 - Machine Gnostic loss - hi : 4723.0758, rentropy: 0.603
# Iteration: 65 - Machine Gnostic loss - hi : 4722.7973, rentropy: 0.6032
# Iteration: 66 - Machine Gnostic loss - hi : 4722.5576, rentropy: 0.6033
# Iteration: 67 - Machine Gnostic loss - hi : 4722.3963, rentropy: 0.6033
# Iteration: 68 - Machine Gnostic loss - hi : 4722.1447, rentropy: 0.6035
# Iteration: 69 - Machine Gnostic loss - hi : 4721.9951, rentropy: 0.6035
# Iteration: 70 - Machine Gnostic loss - hi : 4721.7281, rentropy: 0.6037
# Iteration: 71 - Machine Gnostic loss - hi : 4721.589, rentropy: 0.6037
# Iteration: 72 - Machine Gnostic loss - hi : 4721.396, rentropy: 0.6038
# Iteration: 73 - Machine Gnostic loss - hi : 4721.0826, rentropy: 0.604
# Iteration: 74 - Machine Gnostic loss - hi : 4720.7541, rentropy: 0.604
# Iteration: 75 - Machine Gnostic loss - hi : 4720.856, rentropy: 0.6041
# Iteration: 76 - Machine Gnostic loss - hi : 4720.7827, rentropy: 0.6041
# Iteration: 77 - Machine Gnostic loss - hi : 4720.5016, rentropy: 0.6044
# Iteration: 78 - Machine Gnostic loss - hi : 4720.4229, rentropy: 0.6044
# Iteration: 79 - Machine Gnostic loss - hi : 4720.2352, rentropy: 0.6045
# Iteration: 80 - Machine Gnostic loss - hi : 4720.1625, rentropy: 0.6045
# Iteration: 81 - Machine Gnostic loss - hi : 4719.9694, rentropy: 0.6046
# Iteration: 82 - Machine Gnostic loss - hi : 4719.9009, rentropy: 0.6046
# Iteration: 83 - Machine Gnostic loss - hi : 4719.7184, rentropy: 0.6048
# Iteration: 84 - Machine Gnostic loss - hi : 4719.6861, rentropy: 0.6047
# Iteration: 85 - Machine Gnostic loss - hi : 4719.5741, rentropy: 0.6048
# Iteration: 86 - Machine Gnostic loss - hi : 4719.4672, rentropy: 0.6048
# Iteration: 87 - Machine Gnostic loss - hi : 4719.398, rentropy: 0.6048
# Iteration: 88 - Machine Gnostic loss - hi : 4719.2469, rentropy: 0.6049
# Iteration: 89 - Machine Gnostic loss - hi : 4718.9274, rentropy: 0.6048
# Iteration: 90 - Machine Gnostic loss - hi : 4719.0674, rentropy: 0.605
# Iteration: 91 - Machine Gnostic loss - hi : 4719.0322, rentropy: 0.605
# Iteration: 92 - Machine Gnostic loss - hi : 4718.8952, rentropy: 0.6051
# Iteration: 93 - Machine Gnostic loss - hi : 4718.7965, rentropy: 0.6052
# Iteration: 94 - Machine Gnostic loss - hi : 4718.7357, rentropy: 0.6052
# Iteration: 95 - Machine Gnostic loss - hi : 4718.6879, rentropy: 0.6052
# Iteration: 96 - Machine Gnostic loss - hi : 4718.5655, rentropy: 0.6053
# Iteration: 97 - Machine Gnostic loss - hi : 4718.5278, rentropy: 0.6053
# Iteration: 98 - Machine Gnostic loss - hi : 4718.4093, rentropy: 0.6054
# Iteration: 99 - Machine Gnostic loss - hi : 4718.328, rentropy: 0.6054
# Iteration: 100 - Machine Gnostic loss - hi : 4718.329, rentropy: 0.6053

# %%
import matplotlib.pyplot as plt

# Predict on train and test data
y_train_pred = rr.predict(X_train)
y_test_pred = rr.predict(X_test)

plt.figure(figsize=(12, 5))

# Train plot
plt.subplot(1, 2, 1)
plt.scatter(y_train, y_train_pred, alpha=0.6, color='tab:blue', edgecolor='k')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'r--', lw=2)
plt.xlabel('True Label (Train)', fontsize=12)
plt.ylabel('Predicted Label (Train)', fontsize=12)
plt.title('Train: True vs Predicted', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)

# Test plot
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred, alpha=0.6, color='tab:orange', edgecolor='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('True Label (Test)', fontsize=12)
plt.ylabel('Predicted Label (Test)', fontsize=12)
plt.title('Test: True vs Predicted', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# evaluating the model
from machinegnostics.metrics import robr2, root_mean_squared_error, r2_score, hc

from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# Ensure targets are 1D arrays after splitting (do this once after train_test_split)
y_train = np.array(y_train).squeeze()
y_test = np.array(y_test).squeeze()

# Predict on train and test data
y_train_pred = rr.predict(X_train)
y_test_pred = rr.predict(X_test)

# Calculate metrics (no need for .ravel())
train_r2 = robr2(y_train, y_train_pred, w=rr.weights)
test_r2 = robr2(y_test, y_test_pred)
# Statistical r2
Statistical_train_r2 = r2_score(y_train, y_train_pred)
Statistical_test_r2 = r2_score(y_test, y_test_pred)

train_rmse = root_mean_squared_error(y_train, y_train_pred)
test_rmse = root_mean_squared_error(y_test, y_test_pred)

# calculate hc
train_hc = hc(y_train, y_train_pred, case='i')
test_hc = hc(y_test, y_test_pred, case='i')

# sklearn r2
sklearn_train_r2 = r2_score(y_train, y_train_pred)
sklearn_test_r2 = r2_score(y_test, y_test_pred)


# accuracy
train_accuracy = accuracy_score(y_train, np.round(y_train_pred))
test_accuracy = accuracy_score(y_test, np.round(y_test_pred))

print(f"Train Robust R2: {train_r2:.4f}")
print(f"Test Robust R2: {test_r2:.4f}")
print(f"Train RMSE: {train_rmse:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Train Statistical R2: {Statistical_train_r2:.4f}")
print(f"Test Statistical R2: {Statistical_test_r2:.4f}")
print(f"Train H gnostic relevance: {train_hc:.4f}")
print(f"Test H gnostic relevance: {test_hc:.4f}")
print(f"Sklearn Train R2: {sklearn_train_r2:.4f}")
print(f"Sklearn Test R2: {sklearn_test_r2:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Train Robust R2: 0.9935
# Test Robust R2: 0.3001
# Train RMSE: 0.7093
# Test RMSE: 0.7061
# Train Statistical R2: 0.3515
# Test Statistical R2: 0.2967
# Train H gnostic relevance: 0.0531
# Test H gnostic relevance: 0.0534
# Sklearn Train R2: 0.3515
# Sklearn Test R2: 0.2967
# Train Accuracy: 0.5520
# Test Accuracy: 0.5392

# %%
import matplotlib.pyplot as plt
import numpy as np

history = rr._history

# Remove entries with None for plotting
history_valid = [h for h in history if h['h_loss'] is not None]

iterations = [h['iteration'] for h in history_valid]
h_loss = [h['h_loss'] for h in history_valid]
rentropy = [h['rentropy'] for h in history_valid]
coef_0 = [h['coefficients'][0] for h in history_valid]
mean_weights = [np.mean(h['weights']) for h in history_valid]

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

axes[0, 0].plot(iterations, h_loss, marker='o', color='tab:blue')
axes[0, 0].set_title('h_loss over Iterations')
axes[0, 0].set_xlabel('Iteration')
axes[0, 0].set_ylabel('h_loss')
axes[0, 0].grid(True, linestyle='--', alpha=0.6)

axes[0, 1].plot(iterations, rentropy, marker='s', color='tab:orange')
axes[0, 1].set_title('Rentropy over Iterations')
axes[0, 1].set_xlabel('Iteration')
axes[0, 1].set_ylabel('Rentropy')
axes[0, 1].grid(True, linestyle='--', alpha=0.6)

axes[1, 0].plot(iterations, coef_0, marker='^', color='tab:green')
axes[1, 0].set_title('First Coefficient over Iterations')
axes[1, 0].set_xlabel('Iteration')
axes[1, 0].set_ylabel('1st Coefficient')
axes[1, 0].grid(True, linestyle='--', alpha=0.6)

axes[1, 1].plot(iterations, mean_weights, marker='x', color='tab:red')
axes[1, 1].set_title('Mean Weight over Iterations')
axes[1, 1].set_xlabel('Iteration')
axes[1, 1].set_ylabel('Mean Weight')
axes[1, 1].grid(True, linestyle='--', alpha=0.6)

plt.suptitle('Model History Properties', fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()
